# %% [markdown]
# # GRU

# %%
from tensorflow.keras.layers import GRU

# Define the model
model_gru = Sequential([
    GRU(128, return_sequences=True, input_shape=(TIME_STEPS, FEATURES)),  # First LSTM layer
    Dropout(0.2),  # Dropout to prevent overfitting
    GRU(64, return_sequences=True),  # Second LSTM layer
    Dropout(0.2),
    GRU(32),  # Final LSTM layer
    Dense(64, activation='relu'),  # Fully connected layer
    Dropout(0.2),
    Dense(13, activation='softmax')  # Output layer (adjust 13 based on your classes)
])

# Compile the model
model_gru.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


# Define the learning rate scheduler
lr_scheduler2 = ReduceLROnPlateau(
    monitor='val_loss',    # Monitor validation loss
    factor=0.5,            # Reduce learning rate by half
    patience=3,            # Wait for 3 epochs before reducing
    min_lr=1e-6,           # Set a lower bound for learning rate
    verbose=1              # Print updates
)

# Train LSTM model with the callback
history_gru = model_gru.fit(
    X_train_seq, y_train_seq,
    epochs=50, batch_size=32,
    validation_split=0.2,
    callbacks=[lr_scheduler2]  # Add the callback here
)
# Out:
# D:\ICT\anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 45s 46ms/step - accuracy: 0.3376 - loss: 1.9420 - val_accuracy: 0.6736 - val_loss: 1.0188 - learning_rate: 0.0010
# Epoch 2/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.6806 - loss: 1.0005 - val_accuracy: 0.7484 - val_loss: 0.7409 - learning_rate: 0.0010
# Epoch 3/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 43s 47ms/step - accuracy: 0.7513 - loss: 0.7347 - val_accuracy: 0.8054 - val_loss: 0.5497 - learning_rate: 0.0010
# Epoch 4/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 41s 48ms/step - accuracy: 0.7995 - loss: 0.5878 - val_accuracy: 0.8202 - val_loss: 0.5212 - learning_rate: 0.0010
# Epoch 5/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 43s 50ms/step - accuracy: 0.8255 - loss: 0.5057 - val_accuracy: 0.8290 - val_loss: 0.4914 - learning_rate: 0.0010
# Epoch 6/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 45s 52ms/step - accuracy: 0.8380 - loss: 0.4653 - val_accuracy: 0.8738 - val_loss: 0.3827 - learning_rate: 0.0010
# Epoch 7/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - accuracy: 0.8643 - loss: 0.4007 - val_accuracy: 0.8707 - val_loss: 0.3749 - learning_rate: 0.0010
# Epoch 8/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 43s 51ms/step - accuracy: 0.8832 - loss: 0.3601 - val_accuracy: 0.8985 - val_loss: 0.3042 - learning_rate: 0.0010
# Epoch 9/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 43s 51ms/step - accuracy: 0.8981 - loss: 0.3138 - val_accuracy: 0.8957 - val_loss: 0.3004 - learning_rate: 0.0010
# Epoch 10/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 44s 52ms/step - accuracy: 0.9029 - loss: 0.2936 - val_accuracy: 0.9159 - val_loss: 0.2412 - learning_rate: 0.0010
# Epoch 11/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 45s 52ms/step - accuracy: 0.9135 - loss: 0.2604 - val_accuracy: 0.9166 - val_loss: 0.2477 - learning_rate: 0.0010
# Epoch 12/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 43s 50ms/step - accuracy: 0.9178 - loss: 0.2519 - val_accuracy: 0.9154 - val_loss: 0.2703 - learning_rate: 0.0010
# Epoch 13/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9226 - loss: 0.2393
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - accuracy: 0.9226 - loss: 0.2393 - val_accuracy: 0.9157 - val_loss: 0.2549 - learning_rate: 0.0010
# Epoch 14/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - accuracy: 0.9412 - loss: 0.1819 - val_accuracy: 0.9370 - val_loss: 0.1782 - learning_rate: 5.0000e-04
# Epoch 15/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - accuracy: 0.9454 - loss: 0.1659 - val_accuracy: 0.9352 - val_loss: 0.2047 - learning_rate: 5.0000e-04
# Epoch 16/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 45s 53ms/step - accuracy: 0.9487 - loss: 0.1513 - val_accuracy: 0.9487 - val_loss: 0.1441 - learning_rate: 5.0000e-04
# Epoch 17/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 46s 53ms/step - accuracy: 0.9441 - loss: 0.1713 - val_accuracy: 0.9564 - val_loss: 0.1405 - learning_rate: 5.0000e-04
# Epoch 18/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 45s 52ms/step - accuracy: 0.9534 - loss: 0.1439 - val_accuracy: 0.9554 - val_loss: 0.1318 - learning_rate: 5.0000e-04
# Epoch 19/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 45s 53ms/step - accuracy: 0.9561 - loss: 0.1420 - val_accuracy: 0.9476 - val_loss: 0.1552 - learning_rate: 5.0000e-04
# Epoch 20/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 45s 52ms/step - accuracy: 0.9574 - loss: 0.1341 - val_accuracy: 0.9612 - val_loss: 0.1211 - learning_rate: 5.0000e-04
# Epoch 21/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 79s 49ms/step - accuracy: 0.9585 - loss: 0.1252 - val_accuracy: 0.9547 - val_loss: 0.1436 - learning_rate: 5.0000e-04
# Epoch 22/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 81s 48ms/step - accuracy: 0.9627 - loss: 0.1200 - val_accuracy: 0.9630 - val_loss: 0.1170 - learning_rate: 5.0000e-04
# Epoch 23/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 40s 47ms/step - accuracy: 0.9617 - loss: 0.1217 - val_accuracy: 0.9611 - val_loss: 0.1271 - learning_rate: 5.0000e-04
# Epoch 24/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 43s 50ms/step - accuracy: 0.9584 - loss: 0.1306 - val_accuracy: 0.9617 - val_loss: 0.1155 - learning_rate: 5.0000e-04
# Epoch 25/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - accuracy: 0.9646 - loss: 0.1137 - val_accuracy: 0.9535 - val_loss: 0.1500 - learning_rate: 5.0000e-04
# Epoch 26/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 79s 48ms/step - accuracy: 0.9633 - loss: 0.1164 - val_accuracy: 0.9647 - val_loss: 0.1183 - learning_rate: 5.0000e-04
# Epoch 27/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9658 - loss: 0.1081
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 82s 48ms/step - accuracy: 0.9658 - loss: 0.1081 - val_accuracy: 0.9557 - val_loss: 0.1448 - learning_rate: 5.0000e-04
# Epoch 28/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 41s 48ms/step - accuracy: 0.9709 - loss: 0.0934 - val_accuracy: 0.9734 - val_loss: 0.0926 - learning_rate: 2.5000e-04
# Epoch 29/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 43s 50ms/step - accuracy: 0.9730 - loss: 0.0865 - val_accuracy: 0.9710 - val_loss: 0.0933 - learning_rate: 2.5000e-04
# Epoch 30/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 44s 52ms/step - accuracy: 0.9737 - loss: 0.0826 - val_accuracy: 0.9741 - val_loss: 0.0867 - learning_rate: 2.5000e-04
# Epoch 31/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 45s 52ms/step - accuracy: 0.9746 - loss: 0.0866 - val_accuracy: 0.9724 - val_loss: 0.0908 - learning_rate: 2.5000e-04
# Epoch 32/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 49s 58ms/step - accuracy: 0.9738 - loss: 0.0826 - val_accuracy: 0.9729 - val_loss: 0.0897 - learning_rate: 2.5000e-04
# Epoch 33/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 46s 53ms/step - accuracy: 0.9755 - loss: 0.0795 - val_accuracy: 0.9731 - val_loss: 0.0863 - learning_rate: 2.5000e-04
# Epoch 34/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 78s 48ms/step - accuracy: 0.9751 - loss: 0.0783 - val_accuracy: 0.9710 - val_loss: 0.0824 - learning_rate: 2.5000e-04
# Epoch 35/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 42s 49ms/step - accuracy: 0.9761 - loss: 0.0788 - val_accuracy: 0.9710 - val_loss: 0.0886 - learning_rate: 2.5000e-04
# Epoch 36/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 42s 49ms/step - accuracy: 0.9760 - loss: 0.0762 - val_accuracy: 0.9709 - val_loss: 0.0863 - learning_rate: 2.5000e-04
# Epoch 37/50
# 854/855 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9761 - loss: 0.0749
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 83s 51ms/step - accuracy: 0.9761 - loss: 0.0749 - val_accuracy: 0.9700 - val_loss: 0.0986 - learning_rate: 2.5000e-04
# Epoch 38/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 81s 50ms/step - accuracy: 0.9783 - loss: 0.0661 - val_accuracy: 0.9783 - val_loss: 0.0715 - learning_rate: 1.2500e-04
# Epoch 39/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 41s 48ms/step - accuracy: 0.9821 - loss: 0.0639 - val_accuracy: 0.9735 - val_loss: 0.0858 - learning_rate: 1.2500e-04
# Epoch 40/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 44s 52ms/step - accuracy: 0.9831 - loss: 0.0563 - val_accuracy: 0.9773 - val_loss: 0.0714 - learning_rate: 1.2500e-04
# Epoch 41/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 46s 54ms/step - accuracy: 0.9827 - loss: 0.0601 - val_accuracy: 0.9786 - val_loss: 0.0728 - learning_rate: 1.2500e-04
# Epoch 42/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 47s 55ms/step - accuracy: 0.9821 - loss: 0.0605 - val_accuracy: 0.9794 - val_loss: 0.0696 - learning_rate: 1.2500e-04
# Epoch 43/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 51s 60ms/step - accuracy: 0.9840 - loss: 0.0544 - val_accuracy: 0.9814 - val_loss: 0.0626 - learning_rate: 1.2500e-04
# Epoch 44/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 75s 52ms/step - accuracy: 0.9862 - loss: 0.0502 - val_accuracy: 0.9779 - val_loss: 0.0696 - learning_rate: 1.2500e-04
# Epoch 45/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 47s 55ms/step - accuracy: 0.9841 - loss: 0.0542 - val_accuracy: 0.9775 - val_loss: 0.0709 - learning_rate: 1.2500e-04
# Epoch 46/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9847 - loss: 0.0544
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 48s 56ms/step - accuracy: 0.9847 - loss: 0.0544 - val_accuracy: 0.9819 - val_loss: 0.0634 - learning_rate: 1.2500e-04
# Epoch 47/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 48s 56ms/step - accuracy: 0.9885 - loss: 0.0399 - val_accuracy: 0.9842 - val_loss: 0.0587 - learning_rate: 6.2500e-05
# Epoch 48/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 46s 54ms/step - accuracy: 0.9891 - loss: 0.0413 - val_accuracy: 0.9862 - val_loss: 0.0514 - learning_rate: 6.2500e-05
# Epoch 49/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 52s 60ms/step - accuracy: 0.9893 - loss: 0.0389 - val_accuracy: 0.9827 - val_loss: 0.0666 - learning_rate: 6.2500e-05
# Epoch 50/50
# 855/855 ━━━━━━━━━━━━━━━━━━━━ 47s 55ms/step - accuracy: 0.9894 - loss: 0.0384 - val_accuracy: 0.9871 - val_loss: 0.0494 - learning_rate: 6.2500e-05

# %%
# Load the saved training history
history_data = history_gru.history

# Plot Accuracy
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history_data['accuracy'], label='Train Accuracy')
plt.plot(history_data['val_accuracy'], label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Model Accuracy Over Epochs")

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history_data['loss'], label='Train Loss')
plt.plot(history_data['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Model Loss Over Epochs")

plt.show()

# %%
# Evaluate full models
print("Evaluating Full GRU Model:")
evaluate_model(model_gru, X_test_seq, y_test_seq)
# Out:
# Evaluating Full GRU Model:
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# Accuracy: 98.50%
# F1-score: 98.49%
# Inference Time: 0.496 ms/sample
# (98.5020479812756, 98.48949669967772, 0.49622559700882735)

# %%
# Save the trained RNN model
#model_rnn.save("rnn_model.h5")  # Saves in HDF5 format
model_gru.save("gru_model_50epoch.keras")
# save the history of the model
np.save("gru_training_history_50epoch.npy", history_gru.history)
